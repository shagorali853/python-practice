# %% [markdown]
# # 1. Introduction to Python

# %%
print(7)
# Out:
# 7

# %%
print('hello, world!')
# Out:
# hello, world!

# %% [markdown]
# # 2. Python Syntax

# %%
age = 19

if age >= 18:
print('You are an adult.') # must be indented with 4 spaces
# Out:
#   Cell In[3], line 4
#     print('You are an adult.')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
age = 19

if age >= 18:
    print('You are an adult.')
# Out:
# You are an adult.

# %%
city = 'Dhaka'
City = 'Chittagong'

print(city)
print(City)
# Out:
# Dhaka
# Chittagong

# %% [markdown]
# # 3. Comments

# %%
# print age
age = 24  # Store user's age

print(age)
# Out:
# 24

# %%
"""
This program calculates
the sum of two numbers.
"""

a = 5
b = 3

print(a + b)
# Out:
# 8

# %%
nums = [2, 7, 11, 15]

# Store the target value
target = 9

print(nums)
print(target)
# Out:
# [2, 7, 11, 15]
# 9

# %% [markdown]
# # 4. Variables

# %%
name = "Alex"
age = 24

print(name)
print(age)
# Out:
# Alex
# 24

# %%
a, b, c = 5, 10, 15

print(a)
print(b)
print(c)
# Out:
# 5
# 10
# 15

# %%
x = y = z = 5

print(x)
print(y)
print(z)
# Out:
# 5
# 5
# 5

# %%
score = 85

print(score)

score = 95

print(score)
# Out:
# 85
# 95

# %%
user_name = 'alex'
id2 = 123
password = '1234'

print(user_name)
print(id2)
print(password)
# Out:
# alex
# 123
# 1234

# %% [markdown]
# # 5. Data Types

# %%
age = 20
price = 19.99
temperature = -5.5

print(age)
print(price)
print(temperature)
# Out:
# 20
# 19.99
# -5.5

# %%
first_city = 'Dhaka'
second_city = "Chittagong"

print(first_city)
print(second_city)
# Out:
# Dhaka
# Chittagong

# %%
is_active = True
is_deleted = False

print(is_active)
print(is_deleted)
# Out:
# True
# False

# %%
result = None

print(result)
# Out:
# None

# %%
nums = [1, 2, 3, 4, 5]

print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
point = (3, 4)

print(point)
# Out:
# (3, 4)

# %%
numbers = {1, 2, 3, 4, 5, 5}

print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
student = {
    'name': 'Alex',
    'age': 22,
    'city': 'New York'
}

print(student)
# Out:
# {'name': 'Alex', 'age': 22, 'city': 'New York'}

# %%
a = 10
b = 10.5
c = "Hello"
d = True
e = None
f = [1, 2, 3]

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'list'>

# %% [markdown]
# # 6. Type Casting

# %%
age = '23'
print(type(age))

age = int(age)
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age = 23
print(type(age))

age = str(age)
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %%
price = 19
print(type(price))

age = float(age)
print(type(age))
# Out:
# <class 'int'>
# <class 'float'>

# %%
price = 19.45
print(type(price))

age = int(age)
print(type(age))
# Out:
# <class 'float'>
# <class 'int'>

# %%
price = "99.99"
print(type(price))

price = float(price)
print(type(price))
# Out:
# <class 'str'>
# <class 'float'>

# %%
price = 99.99
print(type(price))

price = str(price)
print(type(price))
# Out:
# <class 'float'>
# <class 'str'>

# %%
print(bool(0))  
print(bool(1))
# Out:
# False
# True

# %%
print(bool(''))
print(bool('Hello'))
# Out:
# False
# True

# %% [markdown]
# # 7. Input & Output

# %%
name = 'Alex'
age = 23

print(name, age)
# Out:
# Alex 23

# %%
print('ml', 'dl', 'cv', sep=' | ')
# Out:
# ml | dl | cv

# %%
print('hello', end=' ')
print('world!')
# Out:
# hello world!

# %%
name = input('enter your name? ')

print('Your name is:', name)
# Out:
# Your name is: Alex

# %%
age = int(input('enter your age? '))

print('Your age is:', age)
# Out:
# Your age is: 19

# %%
marks = float(input('enter your marks? '))

print('Your marks are:', marks)
# Out:
# Your marks are: 93.5

# %%
a, b = map(int, input('enter two numbers: ').split())

print(a + b)
# Out:
# 30

# %%
a, b = map(int, input().split())

print(a)
print(b)
# Out:
# 13
# 45

# %%
numbers = list(map(int, input().split()))

print(numbers)
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
a, b = map(float, input().split())

print(a)
print(b)
# Out:
# 12.4
# 56.7

# %%
country, city = input().split()

print(country)
print(city)
# Out:
# Bangladesh
# Dhake

# %% [markdown]
# # 8. Basic Built-in Functions

# %%
country = 'Bangladesh'
divisions = ['Dhaka', 'Chittagong', 'Khulna', 'Rajshahi', 'Barisal', 'Sylhet', 'Rangpur', 'Mymensingh']

print(len(country))
print(len(divisions))
# Out:
# 10
# 8

# %%
numbers = [1, 2, 3, 4, 5]

print(len(numbers))
print(sum(numbers))
print(min(numbers))
print(max(numbers))
# Out:
# 5
# 15
# 1
# 5

# %%
print(abs(-10))
print(abs(10))
print(abs(-5.5))
# Out:
# 10
# 10
# 5.5

# %%
numbers = [10, 34, 56, 4, 6]

result = sorted(numbers)
print(result)
# Out:
# [4, 6, 10, 34, 56]

# %%
numbers = [10, 34, 56, 4, 6]

result = sorted(numbers, reverse=True)
print(result)
# Out:
# [56, 34, 10, 6, 4]

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
nums = [10, 20, 30, 40]

for i in range(len(nums)):
    print(i, nums[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %% [markdown]
# # 9. String Formatting

# %%
name = 'Alex'
age = 21

print(f'Your name is {name} and your age is {age} years old.')
# Out:
# Your name is Alex and your age is 21 years old.

# %%
a = 12
b = 12

print(f'sum = {a + b}')
# Out:
# sum = 24

# %%
price = 99.56789

print(f"{price:.2f}")
# Out:
# 99.57

# %%
score = 95.6789

print(f"Score: {score:.2f}%")
# Out:
# Score: 95.68%

# %%
name = 'Alex'
age = 21

print('Your name is {} and your age is {}'.format(name, age))
# Out:
# Your name is Alex and your age is 21

# %%
name = 'Alex'
age = 21

print('Your name is {0} and your age is {1}'.format(name, age))
# Out:
# Your name is Alex and your age is 21

# %%
name = 'Alex'
age = 21

print('Name: %s, Age: %d' % (name, age))
# Out:
# Name: Alex, Age: 21
